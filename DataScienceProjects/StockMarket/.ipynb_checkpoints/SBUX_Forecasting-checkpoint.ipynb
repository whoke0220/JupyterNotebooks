# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta

today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days = 365)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('SBUX',
                   start = start_date,
                   end = end_date,
                   progress = False)

data['Date'] = data.index
date = data[['Date',
             'Open',
             'High',
             'Low',
             'Close',
             'Adj Close',
             'Volume']]
data.reset_index(drop = True, inplace = True)
print(data.tail())
# Out:
#           Open       High        Low      Close  Adj Close    Volume  \
# 246  80.099998  80.699997  77.639999  78.309998  78.309998  15841300
# 247  78.500000  79.220001  78.110001  78.870003  78.870003  10744400
# 248  78.790001  78.800003  77.410004  77.480003  77.480003   8833300
# 249  77.099998  78.320000  76.830002  76.879997  76.879997   9268100
# 250  77.099998  78.879997  77.059998  78.760002  78.760002   9294200
#
#           Date
# 246 2024-05-23
# 247 2024-05-24
# 248 2024-05-28
# 249 2024-05-29
# 250 2024-05-30

# %%
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
plt.figure(figsize = (15, 10))
plt.plot(data['Date'], data['Close'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data["Close"], 
                            model='multiplicative', 
                            period = 30)

fig = plt.figure()
fig = result.plot()
fig.set_size_inches(15, 10)

# %%
pd.plotting.autocorrelation_plot(data['Close'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
from statsmodels.graphics.tsaplots import plot_pacf

plot_pacf(data['Close'],
         lags = 100)

# %%
p, d, q = 6, 1, 2

from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(data["Close"], 
              order=(p,d,q))  
fitted = model.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  251
# Model:                 ARIMA(6, 1, 2)   Log Likelihood                -449.696
# Date:                Fri, 31 May 2024   AIC                            917.392
# Time:                        10:50:31   BIC                            949.085
# Sample:                             0   HQIC                           930.147
#                                 - 251
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8497      0.172      4.942      0.000       0.513       1.187
# ar.L2         -0.7173      0.201     -3.572      0.000      -1.111      -0.324
# ar.L3         -0.0868      0.173     -0.501      0.616      -0.426       0.252
# ar.L4          0.0365      0.153      0.238      0.812      -0.264       0.337
# ar.L5         -0.0968      0.160     -0.604      0.546      -0.411       0.217
# ar.L6          0.0370      0.130      0.285      0.775      -0.217       0.291
# ma.L1         -0.8768      0.150     -5.843      0.000      -1.171      -0.583
# ma.L2          0.8308      0.169      4.905      0.000       0.499       1.163
# sigma2         2.1344      0.077     27.766      0.000       1.984       2.285
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             12815.02
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.17   Skew:                            -2.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                        37.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions = fitted.predict()
print(predictions)
# Out:
# 0        0.000000
# 1       97.519994
# 2       99.479829
# 3      100.069397
# 4       98.214892
#           ...
# 246     80.791948
# 247     78.578154
# 248     78.627775
# 249     77.435855
# 250     76.480626
# Name: predicted_mean, Length: 251, dtype: float64

# %%
import statsmodels.api as sm
import warnings
model=sm.tsa.statespace.SARIMAX(data['Close'],
                                order=(p, d, q),
                                seasonal_order=(p, d, q, 12))
model=model.fit()
print(model.summary())
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  251
# Model:             SARIMAX(6, 1, 2)x(6, 1, 2, 12)   Log Likelihood                -448.045
# Date:                            Fri, 31 May 2024   AIC                            930.089
# Time:                                    10:51:31   BIC                            989.118
# Sample:                                         0   HQIC                           953.879
#                                             - 251
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7303      0.217      3.365      0.001       0.305       1.156
# ar.L2         -0.7198      0.211     -3.415      0.001      -1.133      -0.307
# ar.L3         -0.0757      0.191     -0.397      0.691      -0.449       0.298
# ar.L4          0.0349      0.176      0.199      0.843      -0.309       0.379
# ar.L5         -0.1069      0.156     -0.686      0.492      -0.412       0.198
# ar.L6          0.0179      0.115      0.155      0.877      -0.208       0.244
# ma.L1         -0.7610      0.182     -4.180      0.000      -1.118      -0.404
# ma.L2          0.8230      0.164      5.005      0.000       0.501       1.145
# ar.S.L12      -1.0671      3.625     -0.294      0.768      -8.172       6.038
# ar.S.L24      -0.1297      0.405     -0.320      0.749      -0.924       0.665
# ar.S.L36      -0.0599      0.317     -0.189      0.850      -0.681       0.561
# ar.S.L48      -0.0021      0.221     -0.009      0.992      -0.436       0.432
# ar.S.L60       0.0061      0.194      0.031      0.975      -0.374       0.386
# ar.S.L72      -0.0038      0.150     -0.025      0.980      -0.298       0.290
# ma.S.L12      -0.0102    170.442  -5.98e-05      1.000    -334.071     334.051
# ma.S.L24      -0.9897    167.853     -0.006      0.995    -329.975     327.996
# sigma2         2.1364    362.859      0.006      0.995    -709.054     713.327
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             11660.38
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.06   Skew:                            -2.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions = model.predict(len(data), len(data)+10)
print(predictions)
# Out:
# 251    79.155904
# 252    79.938016
# 253    80.416831
# 254    80.436254
# 255    79.768266
# 256    79.253854
# 257    78.952940
# 258    78.997845
# 259    79.131353
# 260    78.595750
# 261    78.542409
# Name: predicted_mean, dtype: float64

# %%
data["Close"].plot(legend=True, label="Training Data", figsize=(15, 10))
predictions.plot(legend=True, label="Predictions")
# Out:
# <Axes: >
